# %%
import pandas as pd
import requests
from io import StringIO
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from shapely.geometry import Point
import folium

url = "https://raw.githubusercontent.com/Amina212004/MINI_PROJET_ML/refs/heads/data_branch/data/meteorites_final.csv"
token = "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"  

headers = {"Authorization": f"token {token}"}
r = requests.get(url, headers=headers)
r.raise_for_status()  

df = pd.read_csv(StringIO(r.text))
df.head()
# Out:
#        name   year_period    year     recclass      continent    country  \
# 0    Aachen  19th Century  1880.0           L5         Europe    Belgium
# 1    Aarhus  20th Century  1951.0           H6         Europe    Denmark
# 2      Abee  20th Century  1952.0          EH4  North America     Canada
# 3  Acapulco  20th Century  1976.0  Acapulcoite  North America     Mexico
# 4   Achiras  20th Century  1902.0           L6  South America  Argentina
#
#    mass_cleaned mass_bin recclass_clean  fall    reclat hemisphere    reclong  \
# 0          21.0  10-100g             L5  Fell  50.77500      North    6.08333
# 1         720.0  100-1kg             H6  Fell  56.18333      North   10.23333
# 2       50370.0    >10kg             H4  Fell  54.21667      North -113.00000
# 3        1914.0   1-10kg          OTHER  Fell  16.88332      North  -99.90000
# 4         780.0  100-1kg             L6  Fell -33.16667      South  -64.95000
#
#   longitude_zone            period_continent
# 0           East         19th Century_Europe
# 1           East         20th Century_Europe
# 2           West  20th Century_North America
# 3           West  20th Century_North America
# 4           West  20th Century_South America

# %%
import pandas as pd
import numpy as np
import folium
from mlxtend.frequent_patterns import apriori, association_rules

# =============================
# PARTIE 1 : APRIORI ET ANALYSE
# =============================

# -----------------------------
# Préparation Apriori
# -----------------------------
df_apriori = pd.get_dummies(df[['year_period', 'mass_bin', 'continent', 'country', 'recclass_clean']])

# ✅ AMÉLIORATION : Support plus bas pour capturer plus de patterns de types rares
frequent_itemsets = apriori(df_apriori, min_support=0.005, use_colnames=True)

# ✅ AMÉLIORATION : Confidence plus basse pour capturer plus de règles de type
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.2)


# 🔍 ANALYSE DES RÈGLES GÉNÉRÉES
print("\n" + "=" * 100)
print("🔍 ANALYSE DES RÈGLES D'ASSOCIATION GÉNÉRÉES")
print("=" * 100)
print(f"\n📊 Total de règles brutes : {len(rules)}")

# Compter les règles par type de conséquent
type_rules_count = rules[rules['consequents'].apply(lambda x: any('recclass_clean_' in str(item) for item in x))]
geo_rules_count = rules[rules['consequents'].apply(lambda x: any('country_' in str(item) or 'continent_' in str(item) for item in x))]
mass_rules_count = rules[rules['consequents'].apply(lambda x: any('mass_bin_' in str(item) for item in x))]
year_rules_count = rules[rules['consequents'].apply(lambda x: any('year_period_' in str(item) for item in x))]

print(f"\n📋 Répartition par type de prédiction :")
print(f"   • Règles prédisant TYPE  : {len(type_rules_count):4d} ({len(type_rules_count)/len(rules)*100:5.1f}%)")
print(f"   • Règles prédisant GEO   : {len(geo_rules_count):4d} ({len(geo_rules_count)/len(rules)*100:5.1f}%)")
print(f"   • Règles prédisant MASSE : {len(mass_rules_count):4d} ({len(mass_rules_count)/len(rules)*100:5.1f}%)")
print(f"   • Règles prédisant ANNÉE : {len(year_rules_count):4d} ({len(year_rules_count)/len(rules)*100:5.1f}%)")

print(f"\n🎯 Exemples de règles prédisant un TYPE (top 5 par confiance) :")
if not type_rules_count.empty:
    top_type_rules = type_rules_count.sort_values('confidence', ascending=False).head(5)
    print(top_type_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].to_string(index=False))
else:
    print("   ⚠️  Aucune règle prédisant un type trouvée !")

print("=" * 100 + "\n")

# -----------------------------
# Création de mappings pour optimisation
# -----------------------------
YEAR_TO_PERIOD = df.dropna(subset=['year']).set_index('year')['year_period'].to_dict()
MASS_BIN_RANGES = {}

for mb in df['mass_bin'].dropna().unique():
    try:
        parts = mb.replace('g', '').replace('kg', '000').split('-')
        if len(parts) == 2:
            MASS_BIN_RANGES[mb] = (float(parts[0]), float(parts[1]))
    except (ValueError, AttributeError):
        continue


# -----------------------------
# Filtrer les tautologies géographiques
# -----------------------------
def is_geographic_tautology(row):
    """
    Détecte les règles tautologiques comme {continent_X} → {country_X}
    ou {country_X} → {continent_X}
    """
    antecedents = row['antecedents']
    consequents = row['consequents']
    
    # Vérifier si une règle relie continent ↔ country
    has_continent_ant = any('continent_' in str(item) for item in antecedents)
    has_country_cons = any('country_' in str(item) for item in consequents)
    has_country_ant = any('country_' in str(item) for item in antecedents)
    has_continent_cons = any('continent_' in str(item) for item in consequents)
    
    return (has_continent_ant and has_country_cons) or (has_country_ant and has_continent_cons)


def is_type_prediction_rule(row):
    """
    Vérifie si la règle prédit un TYPE de météorite (recclass_clean)
    """
    return any('recclass_clean_' in str(item) for item in row['consequents'])


# -----------------------------
# Filtrer règles selon critères (VERSION OPTIMISÉE + NETTOYÉE)
# -----------------------------
def filter_rules(rules, years=None, mass_bins=None, continents=None):
    """
    Filtre les règles d'association selon les critères utilisateur.
    Élimine les tautologies géographiques et priorise les règles de TYPE.
    """
    user_criteria = set()

    # Traitement des années
    if years:
        for y in years:
            if isinstance(y, (list, tuple)) and len(y) == 2:
                relevant_years = [yr for yr in YEAR_TO_PERIOD.keys() if y[0] <= yr <= y[1]]
                user_criteria.update(f'year_period_{YEAR_TO_PERIOD[yr]}' for yr in relevant_years)
            else:
                if y in YEAR_TO_PERIOD:
                    user_criteria.add(f'year_period_{YEAR_TO_PERIOD[y]}')

    # Traitement des masses
    if mass_bins:
        for m in mass_bins:
            if isinstance(m, (list, tuple)) and len(m) == 2:
                for mb, (low, high) in MASS_BIN_RANGES.items():
                    if m[0] <= low and high <= m[1]:
                        user_criteria.add(f'mass_bin_{mb}')
            else:
                user_criteria.add(f'mass_bin_{m}')

    # Traitement des continents
    if continents:
        user_criteria.update(f'continent_{c}' for c in continents)

    if not user_criteria:
        # Aucun critère : retourner toutes les règles NON tautologiques de TYPE
        filtered = rules[~rules.apply(is_geographic_tautology, axis=1)]
        filtered = filtered[filtered.apply(is_type_prediction_rule, axis=1)]
        return filtered

    # Filtrage : user_criteria dans les antécédents
    filtered = rules[rules['antecedents'].apply(lambda x: user_criteria.issubset(x))]
    
    # ✅ AMÉLIORATION 1 : Éliminer les tautologies géographiques
    filtered = filtered[~filtered.apply(is_geographic_tautology, axis=1)]
    
    # ✅ AMÉLIORATION 2 : Prioriser les règles qui prédisent des TYPES
    type_rules = filtered[filtered.apply(is_type_prediction_rule, axis=1)]
    
    if not type_rules.empty:
        return type_rules
    else:
        # Fallback : retourner les règles non-tautologiques même si pas de type
        return filtered


# -----------------------------
# Type le plus probable avec score combiné
# -----------------------------
def get_most_probable_type(filtered_rules, df_subset):
    """
    Détermine le type de météorite le plus probable selon les règles ou les données.
    """
    type_scores = {}
    
    if not filtered_rules.empty:
        for _, row in filtered_rules.iterrows():
            for item in row['consequents']:
                if 'recclass_clean_' in item:
                    type_name = item.replace('recclass_clean_', '')
                    type_scores[type_name] = type_scores.get(type_name, 0) + row['confidence'] * row['support']

    if type_scores:
        top_type = max(type_scores, key=type_scores.get)
        prob = type_scores[top_type] / sum(type_scores.values())
    else:
        # Fallback : fréquences brutes
        if not df_subset.empty and 'recclass_clean' in df_subset.columns:
            top_type = df_subset['recclass_clean'].value_counts().idxmax()
            prob = df_subset['recclass_clean'].value_counts(normalize=True).max()
        else:
            top_type = "Unknown"
            prob = 0.0

    return top_type, prob, type_scores


# -----------------------------
# Prédire valeurs manquantes selon type (VERSION CONTEXTUELLE)
# -----------------------------
def predict_missing_criteria(df, top_type, user_years=None, user_mass=None, user_continents=None):
    """
    Prédit les critères manquants basés sur le type ET les critères déjà spécifiés.
    ✅ AMÉLIORATION : Prédiction contextuelle (prend en compte les critères existants).
    """
    df_type = df[df['recclass_clean'] == top_type].copy()
    
    # ✅ Filtrer d'abord par les critères utilisateur existants
    if user_years:
        years_flat = []
        for y in user_years:
            if isinstance(y, (list, tuple)) and len(y) == 2:
                years_flat.extend(range(y[0], y[1] + 1))
            else:
                years_flat.append(y)
        df_type = df_type[df_type['year'].isin(years_flat)]
    
    if user_mass:
        mass_mask = pd.Series(False, index=df_type.index)
        for m in user_mass:
            if isinstance(m, (list, tuple)) and len(m) == 2:
                mass_mask |= df_type['mass_cleaned'].between(m[0], m[1])
            else:
                mass_mask |= (df_type['mass_bin'] == m)
        df_type = df_type[mass_mask]
    
    if user_continents:
        df_type = df_type[df_type['continent'].isin(user_continents)]
    
    # ✅ Maintenant prédire basé sur ce sous-ensemble contextuel
    year_pred = user_years if user_years else (df_type['year_period'].mode()[0] if not df_type.empty else None)
    mass_pred = user_mass if user_mass else (df_type['mass_bin'].mode()[0] if not df_type.empty else None)
    continent_pred = user_continents if user_continents else (df_type['continent'].mode()[0] if not df_type.empty else None)

    return year_pred, mass_pred, continent_pred


# -----------------------------
# Infos selon critères RÉELS (utilisateur + prédictions)
# -----------------------------
def get_type_info(df, top_type, user_years=None, user_mass=None, user_continents=None,
                  pred_year=None, pred_mass=None, pred_continent=None):
    """
    Récupère les informations des météorites correspondant au type ET aux critères.
    ✅ AMÉLIORATION : Utilise les prédictions si l'utilisateur n'a rien spécifié.
    """
    df_type = df[df['recclass_clean'] == top_type].copy()

    # ✅ Utiliser les critères utilisateur OU les prédictions
    final_years = user_years
    final_mass = user_mass
    final_continents = user_continents if user_continents else ([pred_continent] if pred_continent else None)

    # Filtrage par année
    if final_years:
        years_flat = []
        for y in final_years:
            if isinstance(y, (list, tuple)) and len(y) == 2:
                years_flat.extend(range(y[0], y[1] + 1))
            else:
                years_flat.append(y)
        df_type = df_type[df_type['year'].isin(years_flat)]

    # Filtrage par masse
    if final_mass:
        mass_mask = pd.Series(False, index=df_type.index)
        for m in final_mass:
            if isinstance(m, (list, tuple)) and len(m) == 2:
                mass_mask |= df_type['mass_cleaned'].between(m[0], m[1])
            else:
                mass_mask |= (df_type['mass_bin'] == m)
        df_type = df_type[mass_mask]

    # Filtrage par continent
    if final_continents:
        df_type = df_type[df_type['continent'].isin(final_continents)]

    names = df_type['name'].tolist()
    countries = df_type['country'].dropna().unique().tolist()
    sample_years = df_type['year'].dropna().tolist()
    mass_bin = df_type['mass_bin'].mode()[0] if not df_type.empty else None

    return names, countries, sample_years, mass_bin, df_type


# -----------------------------
# Statistiques de qualité des règles
# -----------------------------
def get_rules_statistics(filtered_rules):
    """
    Calcule des statistiques sur la qualité des règles filtrées.
    """
    if filtered_rules.empty:
        return {
            'total': 0,
            'type_rules': 0,
            'geo_rules': 0,
            'mean_confidence': 0,
            'mean_lift': 0
        }
    
    type_rules = filtered_rules[filtered_rules.apply(is_type_prediction_rule, axis=1)]
    
    return {
        'total': len(filtered_rules),
        'type_rules': len(type_rules),
        'geo_rules': len(filtered_rules) - len(type_rules),
        'mean_confidence': filtered_rules['confidence'].mean(),
        'mean_lift': filtered_rules['lift'].mean()
    }


# -----------------------------
# Traitement d'une sélection utilisateur (AMÉLIORÉ)
# -----------------------------
def process_user_selection(sel, rules, df):
    """
    Traite une sélection utilisateur complète.
    ✅ AMÉLIORATION : Applique les prédictions au filtrage des points sur la carte.
    """
    # Filtrage des règles
    filtered_rules = filter_rules(rules, sel.get('years'), sel.get('mass'), sel.get('continents'))
    
    # Prédiction du type
    top_type, prob, scores = get_most_probable_type(filtered_rules, df)
    
    # Prédiction des critères manquants
    year_pred, mass_pred, cont_pred = predict_missing_criteria(
        df, top_type, sel.get('years'), sel.get('mass'), sel.get('continents')
    )
    
    # ✅ Récupération des infos avec application des prédictions
    names, countries, sample_years, mass_bin, df_points = get_type_info(
        df, top_type, 
        sel.get('years'), sel.get('mass'), sel.get('continents'),
        year_pred, mass_pred, cont_pred
    )
    
    # Statistiques des règles
    stats = get_rules_statistics(filtered_rules)
    
    return {
        'selection': sel,
        'filtered_rules': filtered_rules,
        'top_type': top_type,
        'probability': prob,
        'type_scores': scores,
        'year_pred': year_pred,
        'mass_pred': mass_pred,
        'continent_pred': cont_pred,
        'names': names,
        'countries': countries,
        'sample_years': sample_years,
        'mass_bin': mass_bin,
        'df_points': df_points,
        'stats': stats
    }


# -----------------------------
# Carte interactive multi-exemples
# -----------------------------
def plot_examples_on_map(examples_info, colors=None, map_file='map.html'):
    """
    Affiche plusieurs exemples sur une carte avec des couleurs différentes.
    """
    if colors is None:
        colors = ['hotpink', 'purple', 'orange', 'blue', 'green', 'darkred', 'yellow', 'red']
    
    m = folium.Map(location=[0, 0], zoom_start=2)
    
    for i, info in enumerate(examples_info):
        df_points = info['df_points']
        color = colors[i % len(colors)]
        
        for _, row in df_points.iterrows():
            if pd.notna(row.get('reclat')) and pd.notna(row.get('reclong')):
                folium.CircleMarker(
                    location=[row['reclat'], row['reclong']],
                    radius=4,
                    popup=f"<b>{row['name']}</b><br>{row.get('mass_cleaned', 'N/A')} g<br>{row.get('country', 'N/A')}",
                    color=color,
                    fill=True,
                    fill_color=color,
                    fill_opacity=0.7
                ).add_to(m)
    
    m.save(map_file)
    print(f"✅ Carte sauvegardée : {map_file}")
    return m


# -----------------------------
# EXÉCUTION : Exemples utilisateur
# -----------------------------
user_selections = [
    {"years": [(1994, 2006)], "mass": ['10-100g'], "continents": ['Africa']},      
    {"years": [2000], "mass": None, "continents": ['Asia']},               
    {"years": [(1900, 1950)], "mass": None, "continents": None},           
]

print("\n" + "=" * 100)
print(" " * 30 + "🌠 ANALYSE DES SÉLECTIONS UTILISATEUR 🌠")
print("=" * 100)

examples_info = []

for i, sel in enumerate(user_selections, 1):
    print(f"\n{'█' * 100}")
    print(f"{'█'} {f'EXEMPLE {i}'.center(96)} {'█'}")
    print(f"{'█' * 100}")
    
    # Affichage des critères d'entrée
    print(f"\n{'─' * 100}")
    print("📥 CRITÈRES D'ENTRÉE :")
    print(f"{'─' * 100}")
    print(f"   • Années      : {sel.get('years') if sel.get('years') else '❌ Non spécifié (sera prédit)'}")
    print(f"   • Masse       : {sel.get('mass') if sel.get('mass') else '❌ Non spécifié (sera prédit)'}")
    print(f"   • Continents  : {sel.get('continents') if sel.get('continents') else '❌ Non spécifié (sera prédit)'}")
    
    # Traitement unifié
    result = process_user_selection(sel, rules, df)
    examples_info.append(result)
    
    # Affichage du type prédit
    print(f"\n{'─' * 100}")
    print("🎯 PRÉDICTION DU TYPE :")
    print(f"{'─' * 100}")
    print(f"   • Type probable       : {result['top_type']}")
    print(f"   • Probabilité         : {result['probability']:.2%}")
    print(f"   • Météorites trouvées : {len(result['df_points'])} points sur la carte")
    
    # Affichage des critères
    print(f"\n{'─' * 100}")
    print("📊 CRITÈRES FINAUX (utilisés pour filtrer les points sur la carte) :")
    print(f"{'─' * 100}")
    
    print(f"\n   📅 ANNÉES :")
    if sel.get('years'):
        print(f"      ✓ Critère utilisateur : {sel['years']}")
    else:
        print(f"      🔮 Prédiction         : {result['year_pred']}")
        if result['sample_years']:
            print(f"      📝 Exemples d'années  : {result['sample_years'][:15]}")
    
    print(f"\n   ⚖️  MASSE :")
    if sel.get('mass'):
        print(f"      ✓ Critère utilisateur : {sel['mass']}")
    else:
        print(f"      🔮 Prédiction         : {result['mass_pred']}")
    
    print(f"\n   🌍 CONTINENT :")
    if sel.get('continents'):
        print(f"      ✓ Critère utilisateur : {sel['continents']}")
    else:
        print(f"      🔮 Prédiction (appliquée au filtrage) : {result['continent_pred']}")
        print(f"      ℹ️  Les points de la carte sont filtrés selon cette prédiction")
    
    # Informations géographiques
    print(f"\n{'─' * 100}")
    print("🗺️  INFORMATIONS GÉOGRAPHIQUES :")
    print(f"{'─' * 100}")
    print(f"   • Nombre de pays : {len(result['countries'])}")
    if result['countries']:
        print(f"   • Pays (échantillon) : {', '.join(result['countries'][:15])}")
        if len(result['countries']) > 15:
            print(f"     ... et {len(result['countries']) - 15} autres pays")
    else:
        print(f"   • ⚠️  Aucun pays trouvé avec ces critères")
    
    # Exemples de météorites
    print(f"\n{'─' * 100}")
    print("☄️  EXEMPLES DE MÉTÉORITES :")
    print(f"{'─' * 100}")
    print(f"   • Nombre total : {len(result['names'])}")
    if result['names']:
        print(f"   • Échantillon  : {', '.join(result['names'][:15])}")
        if len(result['names']) > 15:
            print(f"     ... et {len(result['names']) - 15} autres météorites")
    else:
        print(f"   • ⚠️  Aucune météorite trouvée avec ces critères")
    
    # ✅ AMÉLIORATION 3 : Statistiques de qualité des règles
    print(f"\n{'─' * 100}")
    print("📋 RÈGLES D'ASSOCIATION UTILISÉES :")
    print(f"{'─' * 100}")
    
    if result['stats']['total'] > 0:
        print(f"   ✅ {result['stats']['total']} règle(s) trouvée(s)")
        print(f"   📊 Statistiques :")
        print(f"      • Règles prédisant un TYPE      : {result['stats']['type_rules']}")
        print(f"      • Règles géographiques/autres   : {result['stats']['geo_rules']}")
        print(f"      • Confiance moyenne             : {result['stats']['mean_confidence']:.2%}")
        print(f"      • Lift moyen                    : {result['stats']['mean_lift']:.2f}")
        
        print(f"\n   🔍 Top 10 règles (triées par confiance puis support) :")
        top_rules = result['filtered_rules'][['antecedents', 'consequents', 'support', 'confidence', 'lift']]\
            .sort_values(['confidence', 'support'], ascending=False).head(10)
        print(top_rules.to_string(index=False))
    else:
        print(f"   ⚠️  Aucune règle d'association trouvée car la combinaison des criteres est trop rare")
        print(f"   ℹ️  Utilisation des fréquences brutes du dataset (fallback mode)")
    
    print(f"\n{'█' * 100}\n")

# Génération de la carte
print(f"\n{'=' * 100}")
print(" " * 35 + "🗺️  GÉNÉRATION DE LA CARTE INTERACTIVE 🗺️")
print(f"{'=' * 100}\n")

print("📍 Légende des couleurs sur la carte :")
colors_legend = ['🔴 Rose','🟣 Violet' ,'🟠 Orange', '🔵 Bleu', '🟢 Vert']
for i, (sel, color) in enumerate(zip(user_selections, colors_legend), 1):
    result = examples_info[i-1]
    years_str = str(sel.get('years')) if sel.get('years') else f"Prédit: {result['year_pred']}"
    mass_str = str(sel.get('mass')) if sel.get('mass') else f"Prédit: {result['mass_pred']}"
    cont_str = str(sel.get('continents')) if sel.get('continents') else f"Prédit: {result['continent_pred']}"
    print(f"   {color} - Exemple {i} : Années={years_str}, Masse={mass_str}, Continent={cont_str}")

print()
plot_examples_on_map(examples_info, map_file='map.html')

print(f"\n{'=' * 100}")
print("✅ Analyse terminée ! Ouvrez 'map.html' pour voir la carte interactive.")
print(f"{'=' * 100}\n")
# Out:
# ====================================================================================================
# 🔍 ANALYSE DES RÈGLES D'ASSOCIATION GÉNÉRÉES
# ====================================================================================================
#
# 📊 Total de règles brutes : 2552
#
# 📋 Répartition par type de prédiction :
#    • Règles prédisant TYPE  :  245 (  9.6%)
#    • Règles prédisant GEO   : 1609 ( 63.0%)
#    • Règles prédisant MASSE :  821 ( 32.2%)
#    • Règles prédisant ANNÉE :  935 ( 36.6%)
#
# 🎯 Exemples de règles prédisant un TYPE (top 5 par confiance) :
#                                                 antecedents                                                     consequents  support  confidence      lift
#                   (year_period_20th Century, country_Kenya)                           (continent_Africa, recclass_clean_H6) 0.005638    0.800000 56.257269
# (year_period_20th Century, continent_Africa, country_Kenya)                                             (recclass_clean_H6) 0.005638    0.800000  7.907368
#                   (year_period_20th Century, country_Kenya)                                             (recclass_clean_H6) 0.005638    0.800000  7.907368
#                                             (country_Kenya) (year_period_20th Century, continent_Africa, recclass_clean_H6) 0.005638    0.792952 64.090559
#                           (continent_Africa, country_Kenya)                                             (recclass_clean_H6) 0.005638    0.792952  7.837700
# ====================================================================================================
#
#
# ====================================================================================================
#                               🌠 ANALYSE DES SÉLECTIONS UTILISATEUR 🌠
# ====================================================================================================
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █                                            EXEMPLE 1                                             █
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📥 CRITÈRES D'ENTRÉE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Années      : [(1994, 2006)]
#    • Masse       : ['10-100g']
#    • Continents  : ['Africa']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PRÉDICTION DU TYPE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Type probable       : L6
#    • Probabilité         : 23.78%
#    • Météorites trouvées : 93 points sur la carte
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📊 CRITÈRES FINAUX (utilisés pour filtrer les points sur la carte) :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📅 ANNÉES :
#       ✓ Critère utilisateur : [(1994, 2006)]
#
#    ⚖️  MASSE :
#       ✓ Critère utilisateur : ['10-100g']
#
#    🌍 CONTINENT :
#       ✓ Critère utilisateur : ['Africa']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🗺️  INFORMATIONS GÉOGRAPHIQUES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre de pays : 4
#    • Pays (échantillon) : Libya, Egypt, Morocco, Algeria
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ☄️  EXEMPLES DE MÉTÉORITES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre total : 93
#    • Échantillon  : Dar al Gani 021, Dar al Gani 057, Dar al Gani 1043, Dar al Gani 110, Dar al Gani 162, Dar al Gani 246, Dar al Gani 258, Dar al Gani 278, Dar al Gani 281, Dar al Gani 285, Dar al Gani 314, Dar al Gani 358, Dar al Gani 359, Dar al Gani 360, Dar al Gani 376
#      ... et 78 autres météorites
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📋 RÈGLES D'ASSOCIATION UTILISÉES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ⚠️  Aucune règle d'association trouvée car la combinaison des criteres est trop rare
#    ℹ️  Utilisation des fréquences brutes du dataset (fallback mode)
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █                                            EXEMPLE 2                                             █
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📥 CRITÈRES D'ENTRÉE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Années      : [2000]
#    • Masse       : ❌ Non spécifié (sera prédit)
#    • Continents  : ['Asia']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PRÉDICTION DU TYPE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Type probable       : H5
#    • Probabilité         : 74.99%
#    • Météorites trouvées : 76 points sur la carte
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📊 CRITÈRES FINAUX (utilisés pour filtrer les points sur la carte) :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📅 ANNÉES :
#       ✓ Critère utilisateur : [2000]
#
#    ⚖️  MASSE :
#       🔮 Prédiction         : 100-1kg
#
#    🌍 CONTINENT :
#       ✓ Critère utilisateur : ['Asia']
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🗺️  INFORMATIONS GÉOGRAPHIQUES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre de pays : 3
#    • Pays (échantillon) : Yemen, Oman, Qatar
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ☄️  EXEMPLES DE MÉTÉORITES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre total : 76
#    • Échantillon  : Yafa, Al Huqf 002, Dhofar 021, Dhofar 023, Dhofar 1040, Dhofar 1045, Dhofar 1046, Dhofar 1048, Dhofar 1050, Dhofar 1060, Dhofar 1065, Dhofar 1066, Dhofar 117, Dhofar 131, Dhofar 143
#      ... et 61 autres météorites
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📋 RÈGLES D'ASSOCIATION UTILISÉES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ 6 règle(s) trouvée(s)
#    📊 Statistiques :
#       • Règles prédisant un TYPE      : 6
#       • Règles géographiques/autres   : 0
#       • Confiance moyenne             : 20.97%
#       • Lift moyen                    : 1.06
#
#    🔍 Top 10 règles (triées par confiance puis support) :
#                                                                antecedents         consequents  support  confidence     lift
#               (mass_bin_100-1kg, year_period_21st Century, continent_Asia) (recclass_clean_H5) 0.009741    0.217635 1.193850
# (country_Oman, mass_bin_100-1kg, continent_Asia, year_period_21st Century) (recclass_clean_H5) 0.009616    0.217115 1.190997
#               (mass_bin_100-1kg, year_period_21st Century, continent_Asia) (recclass_clean_L6) 0.009365    0.209237 0.880004
# (country_Oman, mass_bin_100-1kg, continent_Asia, year_period_21st Century) (recclass_clean_L6) 0.009209    0.207921 0.874467
#                                 (continent_Asia, year_period_21st Century) (recclass_clean_H5) 0.018480    0.203518 1.116414
#                   (country_Oman, continent_Asia, year_period_21st Century) (recclass_clean_H5) 0.017979    0.202970 1.113407
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █                                            EXEMPLE 3                                             █
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📥 CRITÈRES D'ENTRÉE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Années      : [(1900, 1950)]
#    • Masse       : ❌ Non spécifié (sera prédit)
#    • Continents  : ❌ Non spécifié (sera prédit)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PRÉDICTION DU TYPE :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Type probable       : L6
#    • Probabilité         : 85.85%
#    • Météorites trouvées : 83 points sur la carte
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📊 CRITÈRES FINAUX (utilisés pour filtrer les points sur la carte) :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#    📅 ANNÉES :
#       ✓ Critère utilisateur : [(1900, 1950)]
#
#    ⚖️  MASSE :
#       🔮 Prédiction         : 1-10kg
#
#    🌍 CONTINENT :
#       🔮 Prédiction (appliquée au filtrage) : North America
#       ℹ️  Les points de la carte sont filtrés selon cette prédiction
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🗺️  INFORMATIONS GÉOGRAPHIQUES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre de pays : 2
#    • Pays (échantillon) : United States of America, Canada
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ☄️  EXEMPLES DE MÉTÉORITES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    • Nombre total : 83
#    • Échantillon  : Athens, Atoka, Aztec, Baldwyn, Bath Furnace, Baxter, Benton, Blanket, Bloomington, Cherokee Springs, Chicora, Colby (Wisconsin), Eagle, Forksville, Holbrook
#      ... et 68 autres météorites
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📋 RÈGLES D'ASSOCIATION UTILISÉES :
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    ✅ 47 règle(s) trouvée(s)
#    📊 Statistiques :
#       • Règles prédisant un TYPE      : 47
#       • Règles géographiques/autres   : 0
#       • Confiance moyenne             : 26.55%
#       • Lift moyen                    : 1.68
#
#    🔍 Top 10 règles (triées par confiance puis support) :
#                                                                            antecedents           consequents  support  confidence      lift
#                                              (year_period_20th Century, country_Kenya)   (recclass_clean_H6) 0.005638    0.800000  7.907368
#                            (year_period_20th Century, continent_Africa, country_Kenya)   (recclass_clean_H6) 0.005638    0.800000  7.907368
#                                             (year_period_20th Century, mass_bin_>10kg) (recclass_clean_IRON) 0.009992    0.402270 13.824400
#                            (year_period_20th Century, mass_bin_100-1kg, country_Libya)   (recclass_clean_L6) 0.007392    0.317204  1.334088
#          (year_period_20th Century, mass_bin_100-1kg, continent_Africa, country_Libya)   (recclass_clean_L6) 0.007392    0.317204  1.334088
#                                              (year_period_20th Century, country_Libya)   (recclass_clean_L6) 0.011245    0.297925  1.253005
#                            (year_period_20th Century, continent_Africa, country_Libya)   (recclass_clean_L6) 0.011245    0.297925  1.253005
#                     (year_period_20th Century, mass_bin_100-1kg, continent_Antarctica)   (recclass_clean_L6) 0.023179    0.295409  1.242423
#                       (year_period_20th Century, mass_bin_100-1kg, country_Antarctica)   (recclass_clean_L6) 0.023179    0.295409  1.242423
# (year_period_20th Century, mass_bin_100-1kg, continent_Antarctica, country_Antarctica)   (recclass_clean_L6) 0.023179    0.295409  1.242423
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
#
# ====================================================================================================
#                                    🗺️  GÉNÉRATION DE LA CARTE INTERACTIVE 🗺️
# ====================================================================================================
#
# 📍 Légende des couleurs sur la carte :
#    🔴 Rose - Exemple 1 : Années=[(1994, 2006)], Masse=['10-100g'], Continent=['Africa']
#    🔵 Bleu - Exemple 2 : Années=[2000], Masse=Prédit: 100-1kg, Continent=['Asia']
#    🟠 Orange - Exemple 3 : Années=[(1900, 1950)], Masse=Prédit: 1-10kg, Continent=Prédit: North America
#
# ✅ Carte sauvegardée : map.html
#
# ====================================================================================================
# ✅ Analyse terminée ! Ouvrez 'map.html' pour voir la carte interactive.
# ====================================================================================================

# %%
# =============================
# PARTIE 2 : ÉVALUATION QUALITÉ
# =============================

def evaluate_rules_quality(rules):
    """
    Évalue la qualité des règles d'association.
    ✅ AMÉLIORATION : Exclut les tautologies géographiques de l'évaluation.
    """
    # Filtrer les tautologies
    eval_df = rules[~rules.apply(is_geographic_tautology, axis=1)].copy()
    
    print(f"\n⚠️  {len(rules) - len(eval_df)} tautologies géographiques exclues de l'évaluation")

    conditions = [
        (eval_df['support'] >= 0.01) & (eval_df['confidence'] >= 0.7) & (eval_df['lift'] >= 1.2),
        (eval_df['support'] >= 0.005) & (eval_df['confidence'] >= 0.5) & (eval_df['lift'] >= 1.0),
        (eval_df['support'] < 0.005) | (eval_df['confidence'] < 0.5) | (eval_df['lift'] < 1.0)
    ]
    labels = ['Forte', 'Moyenne', 'Faible']

    eval_df['quality'] = np.select(conditions, labels, default='Faible')

    summary = eval_df['quality'].value_counts()
    print("\n" + "=" * 80)
    print("ÉVALUATION DE LA QUALITÉ DES RÈGLES")
    print("=" * 80)
    print("\n📊 Résumé des règles (hors tautologies) :")
    print(summary)

    print("\n🔍 Top 5 règles fortes (lift élevé) :")
    strong_rules = eval_df[eval_df['quality'] == 'Forte'].sort_values('lift', ascending=False).head(5)
    if not strong_rules.empty:
        print(strong_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].to_string())
    else:
        print("   Aucune règle forte trouvée.")

    return eval_df

# Lancer l'évaluation
evaluated_rules = evaluate_rules_quality(rules)
# Out:
# ⚠️  845 tautologies géographiques exclues de l'évaluation
#
# ================================================================================
# ÉVALUATION DE LA QUALITÉ DES RÈGLES
# ================================================================================
#
# 📊 Résumé des règles (hors tautologies) :
# quality
# Faible     1090
# Moyenne     430
# Forte       187
# Name: count, dtype: int64
#
# 🔍 Top 5 règles fortes (lift élevé) :
#                                                antecedents                 consequents   support  confidence      lift
# 1794  (country_Oman, recclass_clean_OTHER, continent_Asia)  (year_period_21st Century)  0.011934    0.989610  3.566753
# 645                   (country_Oman, recclass_clean_OTHER)  (year_period_21st Century)  0.011934    0.989610  3.566753
# 520                       (country_Oman, mass_bin_10-100g)  (year_period_21st Century)  0.023523    0.967784  3.488085
# 1611      (country_Oman, continent_Asia, mass_bin_10-100g)  (year_period_21st Century)  0.023523    0.967784  3.488085
# 60                                          (country_Oman)  (year_period_21st Century)  0.088580    0.945503  3.407782

# %%
df[(df['year'] == 1950) & (df['mass_bin'] == '10-100g') & (df['continent'] == 'Europe')]
# Out:
#         name   year_period    year        recclass continent country  \
# 4934  Barcis  20th Century  1950.0  Pallasite, PMG    Europe   Italy
#
#       mass_cleaned mass_bin recclass_clean   fall  reclat hemisphere  reclong  \
# 4934          87.0  10-100g          OTHER  Found    46.1      North    12.35
#
#      longitude_zone     period_continent
# 4934           East  20th Century_Europe
